# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import torch
import torchvision
import torchvision.transforms as transforms
from PIL import Image
from matplotlib.pyplot import imshow
import torchvision.transforms.functional as TF

# %matplotlib inline

# %%
train = pd.read_csv("input/train_folds.csv")
root_dir = "input/captcha_examples/"

# %%
idx = 0
data = train.iloc[idx]
img_name = data.Files
image = Image.open(root_dir + img_name, 'r')
imshow(np.asarray(image))

# %%
tensor.size()
# Out:
# torch.Size([3, 200, 200])

# %%
3*200*200/4
# Out:
# 30000.0

# %%
tensor = TF.to_tensor(image)
img = tensor.resize_((200, 200, 3))
img = img.numpy()
plt.imshow(img)
#ts_mean = torch.mean(tensor, [1,2])
#ts_std = torch.std(tensor, [1,2])
#ts_norm = TF.normalize(tensor, mean=ts_mean, std=ts_std)

# %%
torch.max(ts_norm, dim=[1,2])
#ts_min = torch.min(ts_norm, [1, 2])

#ts_standardized = (ts - ts_min)/(ts_max - ts_min)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-26cc9c4fb408> in <module>
# ----> 1 torch.max(ts_norm, dim=[1,2])
#       2 #ts_min = torch.min(ts_norm, [1, 2])
#       3
#       4 #ts_standardized = (ts - ts_min)/(ts_max - ts_min)
#
# TypeError: max() received an invalid combination of arguments - got (Tensor, dim=list), but expected one of:
#  * (Tensor input)
#  * (Tensor input, name dim, bool keepdim, tuple of Tensors out)
#  * (Tensor input, Tensor other, Tensor out)
#  * (Tensor input, int dim, bool keepdim, tuple of Tensors out)
